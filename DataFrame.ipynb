# %% [markdown]
# <a href="https://colab.research.google.com/github/Nehankur1/PythonPandasDataWrangling/blob/main/DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pandas Data Structures - Sequences & Data Frames
# Create Data Frames using List & Dictionary
import pandas as pd
List1 = ['I','work','in','Data Science']
df0 = pd.DataFrame(List1)
df0
# Out:
#               0
# 0             I
# 1          work
# 2            in
# 3  Data Science

# %%
# Sequences are Labelled Array having one column (data column refered by index)
import pandas as pd
import numpy as np
series = pd.Series(['Ram','Sita','Ajay','Atul','Shyam'])
series
# Out:
# 0      Ram
# 1     Sita
# 2     Ajay
# 3     Atul
# 4    Shyam
# dtype: object

# %%
series[3]
# Out:
# 'Atul'

# %%
#labelled sequence
series1 = pd.Series(['Ram','Sita','Ajay','Atul','Shyam'],['one','two','three','four','five'])
series1
# Out:
# one        Ram
# two       Sita
# three     Ajay
# four      Atul
# five     Shyam
# dtype: object

# %%
series1['four']
# Out:
# 'Atul'

# %%
series1 = pd.Series([1,2,3,4],['usa','uk','sg','hk'])
series1
# Out:
# usa    1
# uk     2
# sg     3
# hk     4
# dtype: int64

# %%
#data frames => building blocks are series
df = pd.DataFrame(['Welcome','to','the','world'])
df
# Out:
#          0
# 0  Welcome
# 1       to
# 2      the
# 3    world

# %%
data = {
    'Name' : ["Agent1","Agent2","Agent3"],
    'Age'  : [40,41,42],
    'Role' : ["Data Scientist","Data Engineer","Data Analytics"],
    'DepartmentID' : ['IT','Hr','Service']
}
df =pd.DataFrame(data)
df
# Out:
#      Name  Age            Role DepartmentID
# 0  Agent1   40  Data Scientist           IT
# 1  Agent2   41   Data Engineer           Hr
# 2  Agent3   42  Data Analytics      Service

# %%
#display Role Column
df.Role
#data type of the output  => Series
# Out:
# 0    Data Scientist
# 1     Data Engineer
# 2    Data Analytics
# Name: Role, dtype: object

# %%
df['Role']
# Out:
# 0    Data Scientist
# 1     Data Engineer
# 2    Data Analytics
# Name: Role, dtype: object

# %%
#For more than 1 column apply 2 brackets [[]]
df[['Age','Role']]
# Out:
#    Age            Role
# 0   40  Data Scientist
# 1   41   Data Engineer
# 2   42  Data Analytics

# %%
# 5*4 dataframe with values
df = pd.DataFrame(np.random.randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])
df
# Out:
#           W         X         Y         Z
# A  0.789849 -0.167375 -1.293761 -0.581212
# B -0.493797 -0.450542  0.603670 -2.244496
# C -0.091628  0.480431 -0.918770 -0.580976
# D  0.562554 -1.348840  0.588653 -0.150311
# E -0.537799 -0.871504  1.691148  0.998261

# %%
df['W']
# Out:
# A    0.789849
# B   -0.493797
# C   -0.091628
# D    0.562554
# E   -0.537799
# Name: W, dtype: float64

# %%
df[['W','Z']]
# Out:
#           W         Z
# A  0.789849 -0.581212
# B -0.493797 -2.244496
# C -0.091628 -0.580976
# D  0.562554 -0.150311
# E -0.537799  0.998261

# %%
# To display row we need to use loc function
df.loc['C']
# Out:
# W   -0.091628
# X    0.480431
# Y   -0.918770
# Z   -0.580976
# Name: C, dtype: float64

# %%
df['New'] = df['X'] + df['Y']
df
# Out:
#           W         X         Y         Z       New
# A  0.789849 -0.167375 -1.293761 -0.581212 -1.461136
# B -0.493797 -0.450542  0.603670 -2.244496  0.153129
# C -0.091628  0.480431 -0.918770 -0.580976 -0.438339
# D  0.562554 -1.348840  0.588653 -0.150311 -0.760187
# E -0.537799 -0.871504  1.691148  0.998261  0.819644

# %%
#axis = 0 (label is row)
#axis = 1 (label is column)
df.drop('New', axis =1)
# Out:
#           W         X         Y         Z
# A  0.789849 -0.167375 -1.293761 -0.581212
# B -0.493797 -0.450542  0.603670 -2.244496
# C -0.091628  0.480431 -0.918770 -0.580976
# D  0.562554 -1.348840  0.588653 -0.150311
# E -0.537799 -0.871504  1.691148  0.998261

# %%
df
# Out:
#           W         X         Y         Z       New
# A  0.789849 -0.167375 -1.293761 -0.581212 -1.461136
# B -0.493797 -0.450542  0.603670 -2.244496  0.153129
# C -0.091628  0.480431 -0.918770 -0.580976 -0.438339
# D  0.562554 -1.348840  0.588653 -0.150311 -0.760187
# E -0.537799 -0.871504  1.691148  0.998261  0.819644

# %%
#inplace = true (will make permanant drop)
df.drop('New', axis = 1, inplace = True)
df
# Out:
#           W         X         Y         Z
# A  0.789849 -0.167375 -1.293761 -0.581212
# B -0.493797 -0.450542  0.603670 -2.244496
# C -0.091628  0.480431 -0.918770 -0.580976
# D  0.562554 -1.348840  0.588653 -0.150311
# E -0.537799 -0.871504  1.691148  0.998261

# %%
df['W']['B']
# Out:
# -0.49379704496020427

# %%
np.random.seed(100)
df = pd.DataFrame(np.random.randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])
df>0
# Out:
#        W     X      Y      Z
# A  False  True   True  False
# B   True  True   True  False
# C  False  True  False   True
# D  False  True   True  False
# E  False  True  False  False

# %%
df['W']>0
# Out:
# A    False
# B     True
# C    False
# D    False
# E    False
# Name: W, dtype: bool

# %%
#wherever condition is true it will display value
df[df>0]
# Out:
#           W         X         Y         Z
# A       NaN  0.342680  1.153036       NaN
# B  0.981321  0.514219  0.221180       NaN
# C       NaN  0.255001       NaN  0.435163
# D       NaN  0.816847  0.672721       NaN
# E       NaN  1.029733       NaN       NaN

# %%
df['W']>0
# Out:
# A    False
# B     True
# C    False
# D    False
# E    False
# Name: W, dtype: bool

# %%
df[df['W']>0]
# as only 2nd value was true so that row is dislayed
# Out:
#           W         X        Y         Z
# B  0.981321  0.514219  0.22118 -1.070043

# %%
#Display value of only column Y which is greater than Zero
df[df['Y']>0]['Y']
# Out:
# A    1.153036
# B    0.221180
# D    0.672721
# Name: Y, dtype: float64

# %%
#Display only column values of X & Z if both are greater than Zero
df[(df['X']>0) & (df['Z']>0)] [['X','Z']]
# Out:
#           X         Z
# C  0.255001  0.435163

# %%
#Display only values of W & Z if either of them is >0
df[(df['W']>0) | (df['Z']>0)] [['W','Z']]
# Out:
#           W         Z
# B  0.981321 -1.070043
# C -0.189496  0.435163

# %%
#Display only values of W & Z if either of them is >0; display only row C
df[(df['W']>0) | (df['Z']>0)] [['W','Z']].loc['C']
# Out:
# W   -0.189496
# Z    0.435163
# Name: C, dtype: float64

# %%
df
# Out:
#           W         X         Y         Z
# A -1.749765  0.342680  1.153036 -0.252436
# B  0.981321  0.514219  0.221180 -1.070043
# C -0.189496  0.255001 -0.458027  0.435163
# D -0.583595  0.816847  0.672721 -0.104411
# E -0.531280  1.029733 -0.438136 -1.118318

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A -1.749765  0.342680  1.153036 -0.252436
# 1     B  0.981321  0.514219  0.221180 -1.070043
# 2     C -0.189496  0.255001 -0.458027  0.435163
# 3     D -0.583595  0.816847  0.672721 -0.104411
# 4     E -0.531280  1.029733 -0.438136 -1.118318

# %%
#Create a dataframe with NAN, Drop NAN on row (Axix=0) &/or column (Axix=1), substitute NAN with other value
data1 = {
    'X': [1,2,3,4,5],
    'Y': [np.nan,6,7,np.nan,8],
    'Z': [9,10,11,np.nan,np.nan]
}
df1 =pd.DataFrame(data1)
df1
# Out:
#    X    Y     Z
# 0  1  NaN   9.0
# 1  2  6.0  10.0
# 2  3  7.0  11.0
# 3  4  NaN   NaN
# 4  5  8.0   NaN

# %%
df1.dropna()
# Out:
#    X    Y     Z
# 1  2  6.0  10.0
# 2  3  7.0  11.0

# %%
#drop on axis = 0 (row)
df1.dropna(axis=0)
# Out:
#    X    Y     Z
# 1  2  6.0  10.0
# 2  3  7.0  11.0

# %%
#drop on axis = 1 (column)
df1.dropna(axis=1)
# Out:
#    X
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df1['Y'].fillna(10)
# Out:
# 0    10.0
# 1     6.0
# 2     7.0
# 3    10.0
# 4     8.0
# Name: Y, dtype: float64

# %%
df1.loc[3].fillna(5)
# Out:
# X    4.0
# Y    5.0
# Z    5.0
# Name: 3, dtype: float64

# %%
df1
# Out:
#    X    Y     Z
# 0  1  NaN   9.0
# 1  2  6.0  10.0
# 2  3  7.0  11.0
# 3  4  NaN   NaN
# 4  5  8.0   NaN

# %%
df1.fillna(df1['X'].mean())
# Out:
#    X    Y     Z
# 0  1  3.0   9.0
# 1  2  6.0  10.0
# 2  3  7.0  11.0
# 3  4  3.0   3.0
# 4  5  8.0   3.0
