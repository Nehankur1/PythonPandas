# %% [markdown]
# <a href="https://colab.research.google.com/github/Nehankur1/PythonPandasDataWrangling/blob/main/TestHTMLRead.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Read from html
import pandas as pd
df = pd.read_html("https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/")
df
# Out:
# [                         Bank NameBank       CityCity StateSt  CertCert  \
#  0                        Citizens Bank       Sac City      IA      8758
#  1             Heartland Tri-State Bank        Elkhart      KS     25851
#  2                  First Republic Bank  San Francisco      CA     59017
#  3                       Signature Bank       New York      NY     57053
#  4                  Silicon Valley Bank    Santa Clara      CA     24735
#  ..                                 ...            ...     ...       ...
#  563                 Superior Bank, FSB       Hinsdale      IL     32646
#  564                Malta National Bank          Malta      OH      6629
#  565    First Alliance Bank & Trust Co.     Manchester      NH     34264
#  566  National State Bank of Metropolis     Metropolis      IL      3815
#  567                   Bank of Honolulu       Honolulu      HI     21029
#
#                   Acquiring InstitutionAI Closing DateClosing  FundFund
# ...

# %%
df[0]
# Out:
#                          Bank NameBank       CityCity StateSt  CertCert  \
# 0                        Citizens Bank       Sac City      IA      8758
# 1             Heartland Tri-State Bank        Elkhart      KS     25851
# 2                  First Republic Bank  San Francisco      CA     59017
# 3                       Signature Bank       New York      NY     57053
# 4                  Silicon Valley Bank    Santa Clara      CA     24735
# ..                                 ...            ...     ...       ...
# 563                 Superior Bank, FSB       Hinsdale      IL     32646
# 564                Malta National Bank          Malta      OH      6629
# 565    First Alliance Bank & Trust Co.     Manchester      NH     34264
# 566  National State Bank of Metropolis     Metropolis      IL      3815
# 567                   Bank of Honolulu       Honolulu      HI     21029
#
#                  Acquiring InstitutionAI Closing DateClosing  FundFund
# ...

# %%
df[0].columns
# Out:
# Index(['Bank NameBank', 'CityCity', 'StateSt', 'CertCert',
#        'Acquiring InstitutionAI', 'Closing DateClosing', 'FundFund'],
#       dtype='object')

# %%
df[0]['Bank NameBank']
# Out:
# 0                          Citizens Bank
# 1               Heartland Tri-State Bank
# 2                    First Republic Bank
# 3                         Signature Bank
# 4                    Silicon Valley Bank
#                      ...
# 563                   Superior Bank, FSB
# 564                  Malta National Bank
# 565      First Alliance Bank & Trust Co.
# 566    National State Bank of Metropolis
# 567                     Bank of Honolulu
# Name: Bank NameBank, Length: 568, dtype: object

# %%
df[0].head(5)
# Out:
#               Bank NameBank       CityCity StateSt  CertCert  \
# 0             Citizens Bank       Sac City      IA      8758
# 1  Heartland Tri-State Bank        Elkhart      KS     25851
# 2       First Republic Bank  San Francisco      CA     59017
# 3            Signature Bank       New York      NY     57053
# 4       Silicon Valley Bank    Santa Clara      CA     24735
#
#                Acquiring InstitutionAI Closing DateClosing  FundFund
# 0            Iowa Trust & Savings Bank    November 3, 2023     10545
# 1               Dream First Bank, N.A.       July 28, 2023     10544
# 2            JPMorgan Chase Bank, N.A.         May 1, 2023     10543
# 3                  Flagstar Bank, N.A.      March 12, 2023     10540
# 4  First–Citizens Bank & Trust Company      March 10, 2023     10539

# %%
# Display name of bank where City is Cooper
df[0][df[0]['CityCity'] == 'Cooper']['Bank NameBank']
# Out:
# 12    The Enloe State Bank
# Name: Bank NameBank, dtype: object

# %%
df[0].info
# Out:
# <bound method DataFrame.info of                          Bank NameBank       CityCity StateSt  CertCert  \
# 0                        Citizens Bank       Sac City      IA      8758
# 1             Heartland Tri-State Bank        Elkhart      KS     25851
# 2                  First Republic Bank  San Francisco      CA     59017
# 3                       Signature Bank       New York      NY     57053
# 4                  Silicon Valley Bank    Santa Clara      CA     24735
# ..                                 ...            ...     ...       ...
# 563                 Superior Bank, FSB       Hinsdale      IL     32646
# 564                Malta National Bank          Malta      OH      6629
# 565    First Alliance Bank & Trust Co.     Manchester      NH     34264
# 566  National State Bank of Metropolis     Metropolis      IL      3815
# 567                   Bank of Honolulu       Honolulu      HI     21029
#
#                  Acquiring InstitutionAI Closing DateClosing  FundFund
# ...

# %%
#Read from Database =>Oracle
from sqlalchemy import create_engine
engine = create_engine("sqlite:///:memory:")
df[0].to_sql("my_table", engine)
sqldf = pd.read_sql("my_table", engine)
sqldf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-b1913c07691f> in <cell line: 5>()
#       3 engine = create_engine("sqlite:///:memory:")
#       4 df[0].to_sql("my_table", engine)
# ----> 5 sqldf = pd.read_sql("my_table", engine)
#       6 sqldf
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     579     if _is_table_name:
#     580         pandas_sql.meta.reflect(bind=pandas_sql.connectable, only=[sql])
# --> 581         return pandas_sql.read_table(
#     582             sql,
#     583             index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_table(self, table_name, index_col, coerce_float, parse_dates, columns, schema, chunksize)
#    1458         """
# ...
